# %% [markdown]
# # Eligiendo el mejor modelo de regresión con Pycaret

# %% [markdown]
# ### 1. Instalamos la librería Pycaret y traemos un Dataset de ella

# %%
# Instalamos la librería pycaret
# !pip install pycaret==3.3.2
# !pip install --upgrade pycaret
# Importamos la librería pycaret y la clase det_data
import pycaret 
from pycaret.datasets import get_data
#Creamos una instancia (objeto, variable) que contendrá los datos de df diabetes
Datos_prueba = get_data(dataset = 'diabetes')
# Out:
# Requirement already satisfied: pycaret==3.3.2 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (8.18.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (8.1.5)
# Requirement already satisfied: tqdm>=4.62.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (4.66.5)
# Requirement already satisfied: numpy<1.27,>=1.21 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (2.1.4)
# Requirement already satisfied: jinja2>=3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (3.1.4)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (2.0.2)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (0.12.3)
# Requirement already satisfied: category-encoders>=2.4.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (6.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (2.1.5)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (8.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (5.10.4)
# Requirement already satisfied: cloudpickle in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (2.1.0)
# Requirement already satisfied: xxhash in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (0.14.3)
# Requirement already satisfied: sktime==0.26.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (2.0.4)
# Requirement already satisfied: wurlitzer in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret==3.3.2) (3.1.1)
# Requirement already satisfied: packaging in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from sktime==0.26.0->pycaret==3.3.2) (24.1)
# Requirement already satisfied: scikit-base<0.8.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from sktime==0.26.0->pycaret==3.3.2) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from category-encoders>=2.4.0->pycaret==3.3.2) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from imbalanced-learn>=0.12.0->pycaret==3.3.2) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from importlib-metadata>=4.12.0->pycaret==3.3.2) (3.20.2)
# Requirement already satisfied: decorator in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (5.14.3)
# Requirement already satisfied: typing-extensions in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (4.12.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret==3.3.2) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret==3.3.2) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret==3.3.2) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (6.4.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret==3.3.2) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret==3.3.2) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret==3.3.2) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from numba>=0.55.0->pycaret==3.3.2) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pandas<2.2.0->pycaret==3.3.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pandas<2.2.0->pycaret==3.3.2) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from plotly>=5.14.0->pycaret==3.3.2) (9.0.0)
# Requirement already satisfied: dash>=2.9.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret==3.3.2) (2.18.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret==3.3.2) (3.10.7)
# Requirement already satisfied: tsdownsample>=0.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret==3.3.2) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pmdarima>=2.0.4->pycaret==3.3.2) (3.0.11)
# Requirement already satisfied: urllib3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pmdarima>=2.0.4->pycaret==3.3.2) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pmdarima>=2.0.4->pycaret==3.3.2) (75.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from requests>=2.27.1->pycaret==3.3.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from requests>=2.27.1->pycaret==3.3.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from requests>=2.27.1->pycaret==3.3.2) (2024.8.30)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (3.0.4)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (5.0.0)
# Requirement already satisfied: retrying in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (1.3.4)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret==3.3.2) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret==3.3.2) (4.3.6)
# Requirement already satisfied: six in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret==3.3.2) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret==3.3.2) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret==3.3.2) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret==3.3.2) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret==3.3.2) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret==3.3.2) (0.2.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (1.8.2)
# Requirement already satisfied: pycaret in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (8.18.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (8.1.5)
# Requirement already satisfied: tqdm>=4.62.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (4.66.5)
# Requirement already satisfied: numpy<1.27,>=1.21 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (3.1.4)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: category-encoders>=2.4.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (2.1.5)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (8.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (0.14.3)
# Requirement already satisfied: sktime==0.26.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: wurlitzer in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pycaret) (3.1.1)
# Requirement already satisfied: packaging in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from sktime==0.26.0->pycaret) (24.1)
# Requirement already satisfied: scikit-base<0.8.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.20.2)
# Requirement already satisfied: decorator in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing-extensions in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (4.12.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret) (6.4.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pandas<2.2.0->pycaret) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pandas<2.2.0->pycaret) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from plotly>=5.14.0->pycaret) (9.0.0)
# Requirement already satisfied: dash>=2.9.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.18.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.7)
# Requirement already satisfied: tsdownsample>=0.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pmdarima>=2.0.4->pycaret) (3.0.11)
# Requirement already satisfied: urllib3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pmdarima>=2.0.4->pycaret) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pmdarima>=2.0.4->pycaret) (75.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2024.8.30)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.4)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: retrying in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.6)
# Requirement already satisfied: six in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/envs/DEP23-IntroduccionML/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.2)
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %% [markdown]
# ### 2. Configuramos la prueba de regresión

# %%
# Traemos la clase RegressionExperiment
from pycaret.regression import RegressionExperiment
# Instanciamos (creamos un objeto para llamar en futuros scripts) la clase RegressionExperiment
ExperimentoRegresion = RegressionExperiment()

# %%
# Configuramos el experimento
ExperimentoRegresion.setup(Datos_prueba, target='Class variable',session_id=123)
# Out:
# <style type="text/css">
# #T_4cb1d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4cb1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4cb1d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4cb1d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cb1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4cb1d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4cb1d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4cb1d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4cb1d_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4cb1d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4cb1d_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4cb1d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4cb1d_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4cb1d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4cb1d_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4cb1d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4cb1d_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4cb1d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4cb1d_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4cb1d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4cb1d_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4cb1d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_4cb1d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4cb1d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_4cb1d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4cb1d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_4cb1d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4cb1d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_4cb1d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4cb1d_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_4cb1d_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4cb1d_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_4cb1d_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4cb1d_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_4cb1d_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4cb1d_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_4cb1d_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4cb1d_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_4cb1d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4cb1d_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_4cb1d_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4cb1d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4cb1d_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_4cb1d_row18_col1" class="data row18 col1" >47dd</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### El data set tiene 768 registros y 9 características (variables). Una de ellas se quitará por ser el target de la predicción. Del total, entrará con 537 y probará sus resultados con 237.
# #####  Usamos la VALIDACIÓN CRUZADA KFold, cuya técnica divide el conjunto de datos en K partes (o folds). En cada iteración del proceso, se utiliza uno de los folds como conjunto de prueba (con el que valida sus predicciones) y los otros K-1 como conjunto de entrenamiento. Esto se repite K veces.

# %% [markdown]
row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_42855_row5_col1" class="data row5 col1" >0.3507</td>
#       <td id="T_42855_row5_col2" class="data row5 col2" >0.1691</td>
#       <td id="T_42855_row5_col3" class="data row5 col3" >0.4104</td>
#       <td id="T_42855_row5_col4" class="data row5 col4" >0.2309</td>
#       <td id="T_42855_row5_col5" class="data row5 col5" >0.2881</td>
#       <td id="T_42855_row5_col6" class="data row5 col6" >0.5036</td>
#       <td id="T_42855_row5_col7" class="data row5 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_42855_level0_row6" class="row_heading level0 row

# %%
# Mostramos las 5 pruebas que hayan tenido menor error en MSE y R2, ordenandolas según el resultado del R2
Mejores_5modelos = ExperimentoRegresion.compare_models(include=['et','rf','ridge','lr','lar'])
# Out:
# <style type="text/css">
# #T_8adb4 th {
#   text-align: left;
# }
# #T_8adb4_row0_col0, #T_8adb4_row0_col1, #T_8adb4_row0_col5, #T_8adb4_row1_col0, #T_8adb4_row1_col2, #T_8adb4_row1_col3, #T_8adb4_row1_col4, #T_8adb4_row1_col6, #T_8adb4_row2_col0, #T_8adb4_row2_col1, #T_8adb4_row2_col2, #T_8adb4_row2_col3, #T_8adb4_row2_col4, #T_8adb4_row2_col5, #T_8adb4_row2_col6, #T_8adb4_row3_col0, #T_8adb4_row3_col1, #T_8adb4_row3_col2, #T_8adb4_row3_col3, #T_8adb4_row3_col4, #T_8adb4_row3_col5, #T_8adb4_row3_col6, #T_8adb4_row4_col0, #T_8adb4_row4_col1, #T_8adb4_row4_col2, #T_8adb4_row4_col3, #T_8adb4_row4_col4, #T_8adb4_row4_col5, #T_8adb4_row4_col6 {
#   text-align: left;
# }
# #T_8adb4_row0_col2, #T_8adb4_row0_col3, #T_8adb4_row0_col4, #T_8adb4_row0_col6, #T_8adb4_row1_col1, #T_8adb4_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8adb4_row0_col7, #T_8adb4_row1_col7, #T_8adb4_row3_col7, #T_8adb4_row4_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8adb4_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8adb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8adb4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8adb4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8adb4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8adb4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8adb4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8adb4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8adb4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8adb4_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8adb4_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_8adb4_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_8adb4_row0_col1" class="data row0 col1" >0.3223</td>
#       <td id="T_8adb4_row0_col2" class="data row0 col2" >0.1671</td>
#       <td id="T_8adb4_row0_col3" class="data row0 col3" >0.4074</td>
#       <td id="T_8adb4_row0_col4" class="data row0 col4" >0.2395</td>
#       <td id="T_8adb4_row0_col5" class="data row0 col5" >0.2875</td>
#       <td id="T_8adb4_row0_col6" class="data row0 col6" >0.4652</td>
#       <td id="T_8adb4_row0_col7" class="data row0 col7" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_8adb4_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_8adb4_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_8adb4_row1_col1" class="data row1 col1" >0.3166</td>
#       <td id="T_8adb4_row1_col2" class="data row1 col2" >0.1686</td>
#       <td id="T_8adb4_row1_col3" class="data row1 col3" >0.4078</td>
#       <td id="T_8adb4_row1_col4" class="data row1 col4" >0.2343</td>
#       <td id="T_8adb4_row1_col5" class="data row1 col5" >0.2868</td>
#       <td id="T_8adb4_row1_col6" class="data row1 col6" >0.4671</td>
#       <td id="T_8adb4_row1_col7" class="data row1 col7" >0.1510</td>
#     </tr>
#     <tr>
#       <th id="T_8adb4_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_8adb4_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_8adb4_row2_col1" class="data row2 col1" >0.3463</td>
#       <td id="T_8adb4_row2_col2" class="data row2 col2" >0.1683</td>
#       <td id="T_8adb4_row2_col3" class="data row2 col3" >0.4094</td>
#       <td id="T_8adb4_row2_col4" class="data row2 col4" >0.2338</td>
#       <td id="T_8adb4_row2_col5" class="data row2 col5" >0.2871</td>
#       <td id="T_8adb4_row2_col6" class="data row2 col6" >0.4958</td>
#       <td id="T_8adb4_row2_col7" class="data row2 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_8adb4_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_8adb4_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_8adb4_row3_col1" class="data row3 col1" >0.3462</td>
#       <td id="T_8adb4_row3_col2" class="data row3 col2" >0.1684</td>
#       <td id="T_8adb4_row3_col3" class="data row3 col3" >0.4095</td>
#       <td id="T_8adb4_row3_col4" class="data row3 col4" >0.2336</td>
#       <td id="T_8adb4_row3_col5" class="data row3 col5" >0.2872</td>
#       <td id="T_8adb4_row3_col6" class="data row3 col6" >0.4958</td>
#       <td id="T_8adb4_row3_col7" class="data row3 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_8adb4_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_8adb4_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_8adb4_row4_col1" class="data row4 col1" >0.3456</td>
#       <td id="T_8adb4_row4_col2" class="data row4 col2" >0.1686</td>
#       <td id="T_8adb4_row4_col3" class="data row4 col3" >0.4098</td>
#       <td id="T_8adb4_row4_col4" class="data row4 col4" >0.2322</td>
#       <td id="T_8adb4_row4_col5" class="data row4 col5" >0.2871</td>
#       <td id="T_8adb4_row4_col6" class="data row4 col6" >0.4952</td>
#       <td id="T_8adb4_row4_col7" class="data row4 col7" >0.0170</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Ordenamos la tabla anterior en orden descente según el R2
Mejores_3modelosR2 = ExperimentoRegresion.compare_models(sort = 'R2', n_select=3)
# Out:
# <style type="text/css">
# #T_d2587 th {
#   text-align: left;
# }
# #T_d2587_row0_col0, #T_d2587_row0_col1, #T_d2587_row0_col5, #T_d2587_row0_col6, #T_d2587_row1_col0, #T_d2587_row1_col1, #T_d2587_row1_col2, #T_d2587_row1_col3, #T_d2587_row1_col4, #T_d2587_row1_col6, #T_d2587_row2_col0, #T_d2587_row2_col1, #T_d2587_row2_col2, #T_d2587_row2_col3, #T_d2587_row2_col4, #T_d2587_row2_col5, #T_d2587_row2_col6, #T_d2587_row3_col0, #T_d2587_row3_col1, #T_d2587_row3_col2, #T_d2587_row3_col3, #T_d2587_row3_col4, #T_d2587_row3_col5, #T_d2587_row3_col6, #T_d2587_row4_col0, #T_d2587_row4_col1, #T_d2587_row4_col2, #T_d2587_row4_col3, #T_d2587_row4_col4, #T_d2587_row4_col5, #T_d2587_row4_col6, #T_d2587_row5_col0, #T_d2587_row5_col1, #T_d2587_row5_col2, #T_d2587_row5_col3, #T_d2587_row5_col4, #T_d2587_row5_col5, #T_d2587_row5_col6, #T_d2587_row6_col0, #T_d2587_row6_col1, #T_d2587_row6_col2, #T_d2587_row6_col3, #T_d2587_row6_col4, #T_d2587_row6_col5, #T_d2587_row6_col6, #T_d2587_row7_col0, #T_d2587_row7_col1, #T_d2587_row7_col2, #T_d2587_row7_col3, #T_d2587_row7_col4, #T_d2587_row7_col5, #T_d2587_row7_col6, #T_d2587_row8_col0, #T_d2587_row8_col1, #T_d2587_row8_col2, #T_d2587_row8_col3, #T_d2587_row8_col4, #T_d2587_row8_col5, #T_d2587_row8_col6, #T_d2587_row9_col0, #T_d2587_row9_col1, #T_d2587_row9_col2, #T_d2587_row9_col3, #T_d2587_row9_col4, #T_d2587_row9_col5, #T_d2587_row9_col6, #T_d2587_row10_col0, #T_d2587_row10_col1, #T_d2587_row10_col2, #T_d2587_row10_col3, #T_d2587_row10_col4, #T_d2587_row10_col5, #T_d2587_row10_col6, #T_d2587_row11_col0, #T_d2587_row11_col1, #T_d2587_row11_col2, #T_d2587_row11_col3, #T_d2587_row11_col4, #T_d2587_row11_col5, #T_d2587_row11_col6, #T_d2587_row12_col0, #T_d2587_row12_col1, #T_d2587_row12_col2, #T_d2587_row12_col3, #T_d2587_row12_col4, #T_d2587_row12_col5, #T_d2587_row12_col6, #T_d2587_row13_col0, #T_d2587_row13_col1, #T_d2587_row13_col2, #T_d2587_row13_col3, #T_d2587_row13_col4, #T_d2587_row13_col5, #T_d2587_row13_col6, #T_d2587_row14_col0, #T_d2587_row14_col1, #T_d2587_row14_col2, #T_d2587_row14_col3, #T_d2587_row14_col4, #T_d2587_row14_col5, #T_d2587_row14_col6, #T_d2587_row15_col0, #T_d2587_row15_col1, #T_d2587_row15_col2, #T_d2587_row15_col3, #T_d2587_row15_col4, #T_d2587_row15_col5, #T_d2587_row15_col6, #T_d2587_row16_col0, #T_d2587_row16_col2, #T_d2587_row16_col3, #T_d2587_row16_col4, #T_d2587_row16_col5, #T_d2587_row17_col0, #T_d2587_row17_col1, #T_d2587_row17_col2, #T_d2587_row17_col3, #T_d2587_row17_col4, #T_d2587_row17_col5, #T_d2587_row17_col6 {
#   text-align: left;
# }
# #T_d2587_row0_col2, #T_d2587_row0_col3, #T_d2587_row0_col4, #T_d2587_row1_col5, #T_d2587_row16_col1, #T_d2587_row16_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d2587_row0_col7, #T_d2587_row1_col7, #T_d2587_row2_col7, #T_d2587_row4_col7, #T_d2587_row6_col7, #T_d2587_row7_col7, #T_d2587_row9_col7, #T_d2587_row11_col7, #T_d2587_row12_col7, #T_d2587_row13_col7, #T_d2587_row15_col7, #T_d2587_row16_col7, #T_d2587_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d2587_row3_col7, #T_d2587_row5_col7, #T_d2587_row8_col7, #T_d2587_row10_col7, #T_d2587_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d2587">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2587_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d2587_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d2587_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d2587_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d2587_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d2587_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d2587_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d2587_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2587_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_d2587_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_d2587_row0_col1" class="data row0 col1" >0.3223</td>
#       <td id="T_d2587_row0_col2" class="data row0 col2" >0.1671</td>
#       <td id="T_d2587_row0_col3" class="data row0 col3" >0.4074</td>
#       <td id="T_d2587_row0_col4" class="data row0 col4" >0.2395</td>
#       <td id="T_d2587_row0_col5" class="data row0 col5" >0.2875</td>
#       <td id="T_d2587_row0_col6" class="data row0 col6" >0.4652</td>
#       <td id="T_d2587_row0_col7" class="data row0 col7" >0.0990</td>
#     </tr>
#     <tr>
#       <th id="T_d2587_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_d2587_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_d2587_row1_col1" class="data row1 col1" >0.3166</td>
#       <td id="T_d2587_row1_col2" class="data row1 col2" >0.1686</td>
#       <td id="T_d2587_row1_col3" class="data row1 col3" >0.4078</td>
#       <td id="T_d2587_row1_col4" class="data row1 col4" >0.2343</td>
#       <td id="T_d2587_row1_col5" class="data row1 col5" >0.2868</td>
#       <td id="T_d2587_row1_col6" class="data row1 col6" >0.4671</td>
#       <td id="T_d2587_row1_col7" class="data row1 col7" >0.1810</td>
#     </tr>
#     <tr>
#       <th id="T_d2587_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_d2587_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_d2587_row2_col1" class="data row2 col1" >0.3463</td>
#       <td id="T_d2587_row2_col2" class="data row2 col2" >0.1683</td>
#       <td id="T_d2587_row2_col3" class="data row2 col3" >0.4094</td>
#       <td id="T_d2587_row2_col4" class="data row2 col4" >0.2338</td>
#       <td id="T_d2587_row2_col5" class="data row2 col5" >0.2871</td>
#       <td id="T_d2587_row2_col6" class="data row2 col6" >0.4958</td>
#       <td id="T_d2587_row2_col7" class="data row2 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_d2587_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_d2587_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_d2587_row3_col1" class="data row3 col1" >0.3462</td>
#       <td id="T_d2587_row3_col2" class="data row3 col2" >0.1684</td>
#       <td id="T_d2587_row3_col3" class="data row3 col3" >0.4095</td>
#       <td id="T_d2587_row3_col4" class="data row3 col4" >0.2336</td>
#       <td id="T_d2587_row3_col5" class="data row3 col5" >0.2872</td>
#       <td id="T_d2587_row3_col6" class="data row3 col6" >0.4958</td>
#       <td id="T_d2587_row3_col7" class="data row3 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_d2587_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_d2587_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_d2587_row4_col1" class="data row4 col1" >0.3456</td>
#       <td id="T_d2587_row4_col2" class="data row4 col2" >0.1686</td>
#       <td id="T_d2587_row4_col3" class="data row4 col3" >0.4098</td>
#       <td id="T_d2587_row4_col4" class="data row4 col4" >0.2322</td>
#       <td id="T_d2587_row4_col5" class="data row4 col5" >0.2871</td>
#       <td id="T_d2587_row4_col6" class="data row4 col6" >0.4952</td>
#       <td id="T_d2587_row4_col7" class="data row4 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_d2587_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_d2587_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_d2587_row5_col1" class="data row5 col1" >0.3507</td>
#       <td id="T_d2587_row5_col2" class="data row5 col2" >0.1691</td>
#       <td id="T_d2587_row5_col3" class="data row5 col3" >0.4104</td>
#       <td id="T_d2587_row5_col4" class="data row5 col4" >0.2309</td>
#       <td id="T_d2587_row5_col5" class="data row5 col5" >0.2881</td>
#       <td id="T_d2587_row5_col6" class="data row5 col6" >0.5036</td>
#       <td id="T_d2587_row5_col7" class="data row5 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_d2587_level0_row6" class="row_heading level0 row

# %%
# Escogemos nuestro mejor modelo
Mejor_modelo = Mejores_3modelosR2[0]

# %% [markdown]
# ### 4. Cambiamos los hyperparámetros del modelo en la prueba escogida y evaluamos con cuál modelo nos quedamos

# %%
# Tuneamos nuestro modelo, a fin de modificar los hyperparámetros y observar si se genera un modelo mejor
Mejor_modelo_tuneado = ExperimentoRegresion.tune_model(estimator=Mejor_modelo)
# Out:
# <style type="text/css">
# #T_661b3_row10_col0, #T_661b3_row10_col1, #T_661b3_row10_col2, #T_661b3_row10_col3, #T_661b3_row10_col4, #T_661b3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_661b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_661b3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_661b3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_661b3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_661b3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_661b3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_661b3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_661b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_661b3_row0_col0" class="data row0 col0" >0.3864</td>
#       <td id="T_661b3_row0_col1" class="data row0 col1" >0.1829</td>
#       <td id="T_661b3_row0_col2" class="data row0 col2" >0.4277</td>
#       <td id="T_661b3_row0_col3" class="data row0 col3" >0.1519</td>
#       <td id="T_661b3_row0_col4" class="data row0 col4" >0.3047</td>
#       <td id="T_661b3_row0_col5" class="data row0 col5" >0.5551</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_661b3_row1_col0" class="data row1 col0" >0.4230</td>
#       <td id="T_661b3_row1_col1" class="data row1 col1" >0.2128</td>
#       <td id="T_661b3_row1_col2" class="data row1 col2" >0.4613</td>
#       <td id="T_661b3_row1_col3" class="data row1 col3" >0.1440</td>
#       <td id="T_661b3_row1_col4" class="data row1 col4" >0.3086</td>
#       <td id="T_661b3_row1_col5" class="data row1 col5" >0.5822</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_661b3_row2_col0" class="data row2 col0" >0.3659</td>
#       <td id="T_661b3_row2_col1" class="data row2 col1" >0.1666</td>
#       <td id="T_661b3_row2_col2" class="data row2 col2" >0.4082</td>
#       <td id="T_661b3_row2_col3" class="data row2 col3" >0.2276</td>
#       <td id="T_661b3_row2_col4" class="data row2 col4" >0.2879</td>
#       <td id="T_661b3_row2_col5" class="data row2 col5" >0.5422</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_661b3_row3_col0" class="data row3 col0" >0.3791</td>
#       <td id="T_661b3_row3_col1" class="data row3 col1" >0.1895</td>
#       <td id="T_661b3_row3_col2" class="data row3 col2" >0.4353</td>
#       <td id="T_661b3_row3_col3" class="data row3 col3" >0.1474</td>
#       <td id="T_661b3_row3_col4" class="data row3 col4" >0.3008</td>
#       <td id="T_661b3_row3_col5" class="data row3 col5" >0.6057</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_661b3_row4_col0" class="data row4 col0" >0.3551</td>
#       <td id="T_661b3_row4_col1" class="data row4 col1" >0.1661</td>
#       <td id="T_661b3_row4_col2" class="data row4 col2" >0.4075</td>
#       <td id="T_661b3_row4_col3" class="data row4 col3" >0.1723</td>
#       <td id="T_661b3_row4_col4" class="data row4 col4" >0.2906</td>
#       <td id="T_661b3_row4_col5" class="data row4 col5" >0.5789</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_661b3_row5_col0" class="data row5 col0" >0.3446</td>
#       <td id="T_661b3_row5_col1" class="data row5 col1" >0.1456</td>
#       <td id="T_661b3_row5_col2" class="data row5 col2" >0.3816</td>
#       <td id="T_661b3_row5_col3" class="data row5 col3" >0.2740</td>
#       <td id="T_661b3_row5_col4" class="data row5 col4" >0.2762</td>
#       <td id="T_661b3_row5_col5" class="data row5 col5" >0.5112</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_661b3_row6_col0" class="data row6 col0" >0.3548</td>
#       <td id="T_661b3_row6_col1" class="data row6 col1" >0.1560</td>
#       <td id="T_661b3_row6_col2" class="data row6 col2" >0.3950</td>
#       <td id="T_661b3_row6_col3" class="data row6 col3" >0.2516</td>
#       <td id="T_661b3_row6_col4" class="data row6 col4" >0.2803</td>
#       <td id="T_661b3_row6_col5" class="data row6 col5" >0.5618</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_661b3_row7_col0" class="data row7 col0" >0.3873</td>
#       <td id="T_661b3_row7_col1" class="data row7 col1" >0.1832</td>
#       <td id="T_661b3_row7_col2" class="data row7 col2" >0.4281</td>
#       <td id="T_661b3_row7_col3" class="data row7 col3" >0.2201</td>
#       <td id="T_661b3_row7_col4" class="data row7 col4" >0.2977</td>
#       <td id="T_661b3_row7_col5" class="data row7 col5" >0.5477</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_661b3_row8_col0" class="data row8 col0" >0.3413</td>
#       <td id="T_661b3_row8_col1" class="data row8 col1" >0.1437</td>
#       <td id="T_661b3_row8_col2" class="data row8 col2" >0.3791</td>
#       <td id="T_661b3_row8_col3" class="data row8 col3" >0.3592</td>
#       <td id="T_661b3_row8_col4" class="data row8 col4" >0.2682</td>
#       <td id="T_661b3_row8_col5" class="data row8 col5" >0.4862</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_661b3_row9_col0" class="data row9 col0" >0.3514</td>
#       <td id="T_661b3_row9_col1" class="data row9 col1" >0.1586</td>
#       <td id="T_661b3_row9_col2" class="data row9 col2" >0.3983</td>
#       <td id="T_661b3_row9_col3" class="data row9 col3" >0.3103</td>
#       <td id="T_661b3_row9_col4" class="data row9 col4" >0.2704</td>
#       <td id="T_661b3_row9_col5" class="data row9 col5" >0.5657</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_661b3_row10_col0" class="data row10 col0" >0.3689</td>
#       <td id="T_661b3_row10_col1" class="data row10 col1" >0.1705</td>
#       <td id="T_661b3_row10_col2" class="data row10 col2" >0.4122</td>
#       <td id="T_661b3_row10_col3" class="data row10 col3" >0.2258</td>
#       <td id="T_661b3_row10_col4" class="data row10 col4" >0.2885</td>
#       <td id="T_661b3_row10_col5" class="data row10 col5" >0.5537</td>
#     </tr>
#     <tr>
#       <th id="T_661b3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_661b3_row11_col0" class="data row11 col0" >0.0239</td>
#       <td id="T_661b3_row11_col1" class="data row11 col1" >0.0205</td>
#       <td id="T_661b3_row11_col2" class="data row11 col2" >0.0245</td>
#       <td id="T_661b3_row11_col3" class="data row11 col3" >0.0701</td>
#       <td id="T_661b3_row11_col4" class="data row11 col4" >0.0137</td>
#       <td id="T_661b3_row11_col5" class="data row11 col5" >0.0330</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# ##### Escogemos el modelo original por tener el mayor R2(0.2395>0.2258) y menor MSE (0.1671<0.1705)

# %% [markdown]
# ### 5. Terminamos, guardamos y cargamos el modelo ganador

# %%
# Terminamos el modelo ganador
Modelo_final = ExperimentoRegresion.finalize_model(estimator=Mejor_modelo)
Modelo_final
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Number of times pregnant',
#                                              'Plasma glucose concentration a 2 '
#                                              'hours in an oral glucose '
#                                              'tolerance test',
#                                              'Diastolic blood pressure (mm Hg)',
#                                              'Triceps skin fold thickness (mm)',
#                                              '2-Hour serum insulin (mu U/ml)',
#                                              'Body mass index (weight in '
#                                              'kg/(height in m)^2)',
#                                              'Diabetes pedigree function',
#                                              'Age (years)'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ('actual_estimator',
#                  ExtraTreesRegressor(n_jobs=-1, random_state=123))])

# %%
# Guardamos el modelo ganador en Pycaret
ExperimentoRegresion.save_model(model=Modelo_final, model_name= './Modelo_final')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Number of times pregnant',
#                                               'Plasma glucose concentration a 2 '
#                                               'hours in an oral glucose '
#                                               'tolerance test',
#                                               'Diastolic blood pressure (mm Hg)',
#                                               'Triceps skin fold thickness (mm)',
#                                               '2-Hour serum insulin (mu U/ml)',
#                                               'Body mass index (weight in '
#                                               'kg/(height in m)^2)',
#                                               'Diabetes pedigree function',
#                                               'Age (years)'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('actual_estimator',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=123))]),
#  './Modelo_final.pkl')

# %% [markdown]
# ##### Te permite guardar todo el pipeline completo, lo que es conveniente cuando quieres reutilizar el mismo flujo de trabajo (preprocesamiento, selección de características, etc.) más adelante.

# %%
# Guardamos el modelo ganador en Python, para que pueda ser usado con independencia de la librería
# Importamos a librería joblib, que se utiliza para serializar (guardar) objetos en archivos y también para cargarlos de nuevo más adelante.
import joblib
# Guardamos nuestro mejor modelo con la clase
joblib.dump(Mejor_modelo, 'Modelo_final_joblib.pkl')
# Out:
# ['Modelo_final_joblib.pkl']

# %% [markdown]
# ##### Joblib es un método es más flexible y ligero si solo necesitas guardar y cargar el modelo final y no todo el pipeline. Puedes usarlo fuera de PyCaret o en otros contextos. Mas no contiene los detalles del preprocesamiento en Pycaret.

# %%
# Cargamos el modelo ganador como si fueramos a usarlo con la librería Pycaret
Modelo_cargado_desde_disco=ExperimentoRegresion.load_model('./Modelo_final')
# Out:
# Transformation Pipeline and Model Successfully Loaded
