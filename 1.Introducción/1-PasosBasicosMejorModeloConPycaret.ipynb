# %% [markdown]
# # Probar Modelos con PyCaret (TEMPLATE DATAPATH - Prof. Inofuente)

# %% [markdown]
# # Paso 1: Cargamos Pycaret y un Dataset

# %%
import pycaret
pycaret.__version__
# Out:
# '3.3.2'

# %%
from pycaret.datasets import get_data
Datos_traffic = get_data(dataset = 'diabetes') #Aquí cambias el Dataset
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %% [markdown]
# # Paso 2: Importar las Regresiones de Pycaret y Crear el Objeto

# %%
from pycaret.regression import *

# %%
# import RegressionExperiment and init the class
from pycaret.regression import RegressionExperiment
ExperimentoRegresion = RegressionExperiment() #Instanciamos la clase

# %% [markdown]
# # Paso 3: Configurar el Experimento u Objeto

# %%
# init setup on exp
ExperimentoRegresion.setup(Datos_traffic, target = 'Class variable', session_id = 123)
                                          #Coloco la etiqueta de mi Target, en este caso el Volumen del Tráfico
# Out:
# <style type="text/css">
# #T_e1dcd_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e1dcd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1dcd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e1dcd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1dcd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1dcd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e1dcd_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1dcd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e1dcd_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1dcd_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e1dcd_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1dcd_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e1dcd_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1dcd_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e1dcd_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e1dcd_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e1dcd_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e1dcd_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e1dcd_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e1dcd_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e1dcd_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e1dcd_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e1dcd_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e1dcd_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e1dcd_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e1dcd_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e1dcd_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e1dcd_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e1dcd_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e1dcd_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e1dcd_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e1dcd_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e1dcd_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e1dcd_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e1dcd_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e1dcd_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e1dcd_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e1dcd_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e1dcd_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e1dcd_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e1dcd_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e1dcd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e1dcd_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e1dcd_row18_col1" class="data row18 col1" >0a53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Usamos la VALIDACIÓN CRUZADA KFold, cuya técnica divide el conjunto de datos en K partes (o folds). En cada iteración del proceso, se utiliza uno de los folds como conjunto de prueba y los otros K-1 como conjunto de entrenamiento. Esto se repite K veces.

# %% [markdown]
# # Paso 4: Entrenamos y Comparamos los Modelos

# %%
#Comparamos los Modelos usando POO
MejorModelo = ExperimentoRegresion.compare_models()
# Out:
# <style type="text/css">
# #T_78451 th {
#   text-align: left;
# }
# #T_78451_row0_col0, #T_78451_row0_col1, #T_78451_row0_col5, #T_78451_row0_col6, #T_78451_row1_col0, #T_78451_row1_col1, #T_78451_row1_col2, #T_78451_row1_col3, #T_78451_row1_col4, #T_78451_row1_col6, #T_78451_row2_col0, #T_78451_row2_col1, #T_78451_row2_col2, #T_78451_row2_col3, #T_78451_row2_col4, #T_78451_row2_col5, #T_78451_row2_col6, #T_78451_row3_col0, #T_78451_row3_col1, #T_78451_row3_col2, #T_78451_row3_col3, #T_78451_row3_col4, #T_78451_row3_col5, #T_78451_row3_col6, #T_78451_row4_col0, #T_78451_row4_col1, #T_78451_row4_col2, #T_78451_row4_col3, #T_78451_row4_col4, #T_78451_row4_col5, #T_78451_row4_col6, #T_78451_row5_col0, #T_78451_row5_col1, #T_78451_row5_col2, #T_78451_row5_col3, #T_78451_row5_col4, #T_78451_row5_col5, #T_78451_row5_col6, #T_78451_row6_col0, #T_78451_row6_col1, #T_78451_row6_col2, #T_78451_row6_col3, #T_78451_row6_col4, #T_78451_row6_col5, #T_78451_row6_col6, #T_78451_row7_col0, #T_78451_row7_col1, #T_78451_row7_col2, #T_78451_row7_col3, #T_78451_row7_col4, #T_78451_row7_col5, #T_78451_row7_col6, #T_78451_row8_col0, #T_78451_row8_col1, #T_78451_row8_col2, #T_78451_row8_col3, #T_78451_row8_col4, #T_78451_row8_col5, #T_78451_row8_col6, #T_78451_row9_col0, #T_78451_row9_col1, #T_78451_row9_col2, #T_78451_row9_col3, #T_78451_row9_col4, #T_78451_row9_col5, #T_78451_row9_col6, #T_78451_row10_col0, #T_78451_row10_col1, #T_78451_row10_col2, #T_78451_row10_col3, #T_78451_row10_col4, #T_78451_row10_col5, #T_78451_row10_col6, #T_78451_row11_col0, #T_78451_row11_col1, #T_78451_row11_col2, #T_78451_row11_col3, #T_78451_row11_col4, #T_78451_row11_col5, #T_78451_row11_col6, #T_78451_row12_col0, #T_78451_row12_col1, #T_78451_row12_col2, #T_78451_row12_col3, #T_78451_row12_col4, #T_78451_row12_col5, #T_78451_row12_col6, #T_78451_row13_col0, #T_78451_row13_col1, #T_78451_row13_col2, #T_78451_row13_col3, #T_78451_row13_col4, #T_78451_row13_col5, #T_78451_row13_col6, #T_78451_row14_col0, #T_78451_row14_col1, #T_78451_row14_col2, #T_78451_row14_col3, #T_78451_row14_col4, #T_78451_row14_col5, #T_78451_row14_col6, #T_78451_row15_col0, #T_78451_row15_col1, #T_78451_row15_col2, #T_78451_row15_col3, #T_78451_row15_col4, #T_78451_row15_col5, #T_78451_row15_col6, #T_78451_row16_col0, #T_78451_row16_col1, #T_78451_row16_col2, #T_78451_row16_col3, #T_78451_row16_col4, #T_78451_row16_col5, #T_78451_row16_col6, #T_78451_row17_col0, #T_78451_row17_col1, #T_78451_row17_col2, #T_78451_row17_col3, #T_78451_row17_col4, #T_78451_row17_col5, #T_78451_row17_col6, #T_78451_row18_col0, #T_78451_row18_col2, #T_78451_row18_col3, #T_78451_row18_col4, #T_78451_row18_col5, #T_78451_row19_col0, #T_78451_row19_col1, #T_78451_row19_col2, #T_78451_row19_col3, #T_78451_row19_col4, #T_78451_row19_col5, #T_78451_row19_col6 {
#   text-align: left;
# }
# #T_78451_row0_col2, #T_78451_row0_col3, #T_78451_row0_col4, #T_78451_row1_col5, #T_78451_row18_col1, #T_78451_row18_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_78451_row0_col7, #T_78451_row1_col7, #T_78451_row2_col7, #T_78451_row3_col7, #T_78451_row4_col7, #T_78451_row5_col7, #T_78451_row6_col7, #T_78451_row7_col7, #T_78451_row8_col7, #T_78451_row9_col7, #T_78451_row11_col7, #T_78451_row12_col7, #T_78451_row13_col7, #T_78451_row14_col7, #T_78451_row15_col7, #T_78451_row17_col7, #T_78451_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_78451_row10_col7, #T_78451_row16_col7, #T_78451_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_78451">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78451_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_78451_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_78451_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_78451_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_78451_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_78451_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_78451_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_78451_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78451_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_78451_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_78451_row0_col1" class="data row0 col1" >0.3223</td>
#       <td id="T_78451_row0_col2" class="data row0 col2" >0.1671</td>
#       <td id="T_78451_row0_col3" class="data row0 col3" >0.4074</td>
#       <td id="T_78451_row0_col4" class="data row0 col4" >0.2395</td>
#       <td id="T_78451_row0_col5" class="data row0 col5" >0.2875</td>
#       <td id="T_78451_row0_col6" class="data row0 col6" >0.4652</td>
#       <td id="T_78451_row0_col7" class="data row0 col7" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_78451_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_78451_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_78451_row1_col1" class="data row1 col1" >0.3166</td>
#       <td id="T_78451_row1_col2" class="data row1 col2" >0.1686</td>
#       <td id="T_78451_row1_col3" class="data row1 col3" >0.4078</td>
#       <td id="T_78451_row1_col4" class="data row1 col4" >0.2343</td>
#       <td id="T_78451_row1_col5" class="data row1 col5" >0.2868</td>
#       <td id="T_78451_row1_col6" class="data row1 col6" >0.4671</td>
#       <td id="T_78451_row1_col7" class="data row1 col7" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_78451_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_78451_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_78451_row2_col1" class="data row2 col1" >0.3463</td>
#       <td id="T_78451_row2_col2" class="data row2 col2" >0.1683</td>
#       <td id="T_78451_row2_col3" class="data row2 col3" >0.4094</td>
#       <td id="T_78451_row2_col4" class="data row2 col4" >0.2338</td>
#       <td id="T_78451_row2_col5" class="data row2 col5" >0.2871</td>
#       <td id="T_78451_row2_col6" class="data row2 col6" >0.4958</td>
#       <td id="T_78451_row2_col7" class="data row2 col7" >0.1050</td>
#     </tr>
#     <tr>
#       <th id="T_78451_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_78451_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_78451_row3_col1" class="data row3 col1" >0.3462</td>
#       <td id="T_78451_row3_col2" class="data row3 col2" >0.1684</td>
#       <td id="T_78451_row3_col3" class="data row3 col3" >0.4095</td>
#       <td id="T_78451_row3_col4" class="data row3 col4" >0.2336</td>
#       <td id="T_78451_row3_col5" class="data row3 col5" >0.2872</td>
#       <td id="T_78451_row3_col6" class="data row3 col6" >0.4958</td>
#       <td id="T_78451_row3_col7" class="data row3 col7" >0.4240</td>
#     </tr>
#     <tr>
#       <th id="T_78451_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_78451_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_78451_row4_col1" class="data row4 col1" >0.3456</td>
#       <td id="T_78451_row4_col2" class="data row4 col2" >0.1686</td>
#       <td id="T_78451_row4_col3" class="data row4 col3" >0.4098</td>
#       <td id="T_78451_row4_col4" class="data row4 col4" >0.2322</td>
#       <td id="T_78451_row4_col5" class="data row4 col5" >0.2871</td>
#       <td id="T_78451_row4_col6" class="data row4 col6" >0.4952</td>
#       <td id="T_78451_row4_col7" class="data row4 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_78451_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_78451_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_78451_row5_col1" class="data row5 col1" >0.3507</td>
#       <td id="T_78451_row5_col2" class="data row5 col2" >0.1691</td>
#       <td id="T_78451_row5_col3" class="data row5 col3" >0.4104</td>
#       <td id="T_78451_r

# %% [markdown]
# ### *Resolver*
# #### 1. ¿Cuál es el mejor modelo y por qué? Justificar. ¿Qué significa cada métrica?

# %%
print(MejorModelo)
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %%
ExperimentoRegresion.models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# catboost                 CatBoost Regressor
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# xgboost                        xgboost.sklearn.XGBRegressor   True
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# catboost                    catboost.core.CatBoostRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
compare_tree_models = ExperimentoRegresion.compare_models(include = ['dt', 'rf', 'et', 'gbr', 'xgboost', 'lightgbm', 'catboost'])
# Out:
# <style type="text/css">
# #T_bbe3e th {
#   text-align: left;
# }
# #T_bbe3e_row0_col0, #T_bbe3e_row0_col1, #T_bbe3e_row0_col5, #T_bbe3e_row0_col6, #T_bbe3e_row1_col0, #T_bbe3e_row1_col1, #T_bbe3e_row1_col2, #T_bbe3e_row1_col3, #T_bbe3e_row1_col4, #T_bbe3e_row1_col6, #T_bbe3e_row2_col0, #T_bbe3e_row2_col1, #T_bbe3e_row2_col2, #T_bbe3e_row2_col3, #T_bbe3e_row2_col4, #T_bbe3e_row2_col5, #T_bbe3e_row2_col6, #T_bbe3e_row3_col0, #T_bbe3e_row3_col1, #T_bbe3e_row3_col2, #T_bbe3e_row3_col3, #T_bbe3e_row3_col4, #T_bbe3e_row3_col5, #T_bbe3e_row3_col6, #T_bbe3e_row4_col0, #T_bbe3e_row4_col1, #T_bbe3e_row4_col2, #T_bbe3e_row4_col3, #T_bbe3e_row4_col4, #T_bbe3e_row4_col5, #T_bbe3e_row4_col6, #T_bbe3e_row5_col0, #T_bbe3e_row5_col1, #T_bbe3e_row5_col2, #T_bbe3e_row5_col3, #T_bbe3e_row5_col4, #T_bbe3e_row5_col5, #T_bbe3e_row5_col6, #T_bbe3e_row6_col0, #T_bbe3e_row6_col2, #T_bbe3e_row6_col3, #T_bbe3e_row6_col4, #T_bbe3e_row6_col5 {
#   text-align: left;
# }
# #T_bbe3e_row0_col2, #T_bbe3e_row0_col3, #T_bbe3e_row0_col4, #T_bbe3e_row1_col5, #T_bbe3e_row6_col1, #T_bbe3e_row6_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bbe3e_row0_col7, #T_bbe3e_row1_col7, #T_bbe3e_row3_col7, #T_bbe3e_row4_col7, #T_bbe3e_row5_col7, #T_bbe3e_row6_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bbe3e_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bbe3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbe3e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bbe3e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bbe3e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bbe3e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bbe3e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bbe3e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bbe3e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_bbe3e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbe3e_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_bbe3e_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_bbe3e_row0_col1" class="data row0 col1" >0.3223</td>
#       <td id="T_bbe3e_row0_col2" class="data row0 col2" >0.1671</td>
#       <td id="T_bbe3e_row0_col3" class="data row0 col3" >0.4074</td>
#       <td id="T_bbe3e_row0_col4" class="data row0 col4" >0.2395</td>
#       <td id="T_bbe3e_row0_col5" class="data row0 col5" >0.2875</td>
#       <td id="T_bbe3e_row0_col6" class="data row0 col6" >0.4652</td>
#       <td id="T_bbe3e_row0_col7" class="data row0 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_bbe3e_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_bbe3e_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_bbe3e_row1_col1" class="data row1 col1" >0.3166</td>
#       <td id="T_bbe3e_row1_col2" class="data row1 col2" >0.1686</td>
#       <td id="T_bbe3e_row1_col3" class="data row1 col3" >0.4078</td>
#       <td id="T_bbe3e_row1_col4" class="data row1 col4" >0.2343</td>
#       <td id="T_bbe3e_row1_col5" class="data row1 col5" >0.2868</td>
#       <td id="T_bbe3e_row1_col6" class="data row1 col6" >0.4671</td>
#       <td id="T_bbe3e_row1_col7" class="data row1 col7" >0.1590</td>
#     </tr>
#     <tr>
#       <th id="T_bbe3e_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_bbe3e_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_bbe3e_row2_col1" class="data row2 col1" >0.3213</td>
#       <td id="T_bbe3e_row2_col2" class="data row2 col2" >0.1698</td>
#       <td id="T_bbe3e_row2_col3" class="data row2 col3" >0.4096</td>
#       <td id="T_bbe3e_row2_col4" class="data row2 col4" >0.2296</td>
#       <td id="T_bbe3e_row2_col5" class="data row2 col5" >0.2880</td>
#       <td id="T_bbe3e_row2_col6" class="data row2 col6" >0.4687</td>
#       <td id="T_bbe3e_row2_col7" class="data row2 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_bbe3e_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_bbe3e_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_bbe3e_row3_col1" class="data row3 col1" >0.3191</td>
#       <td id="T_bbe3e_row3_col2" class="data row3 col2" >0.1731</td>
#       <td id="T_bbe3e_row3_col3" class="data row3 col3" >0.4141</td>
#       <td id="T_bbe3e_row3_col4" class="data row3 col4" >0.2140</td>
#       <td id="T_bbe3e_row3_col5" class="data row3 col5" >0.2897</td>
#       <td id="T_bbe3e_row3_col6" class="data row3 col6" >0.4634</td>
#       <td id="T_bbe3e_row3_col7" class="data row3 col7" >0.2000</td>
#     </tr>
#     <tr>
#       <th id="T_bbe3e_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_bbe3e_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_bbe3e_row4_col1" class="data row4 col1" >0.3319</td>
#       <td id="T_bbe3e_row4_col2" class="data row4 col2" >0.1955</td>
#       <td id="T_bbe3e_row4_col3" class="data row4 col3" >0.4393</td>
#       <td id="T_bbe3e_row4_col4" class="data row4 col4" >0.1116</td>
#       <td id="T_bbe3e_row4_col5" class="data row4 col5" >0.3052</td>
#       <td id="T_bbe3e_row4_col6" class="data row4 col6" >0.4772</td>
#       <td id="T_bbe3e_row4_col7" class="data row4 col7" >0.1960</td>
#     </tr>
#     <tr>
#       <th id="T_bbe3e_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_bbe3e_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_bbe3e_row5_col1" class="data row5 col1" >0.3328</td>
#       <td id="T_bbe3e_row5_col2" class="data row5 col2" >0.2041</td>
#       <td id="T_bbe3e_row5_col3" class="data row5 col3" >0.4495</td>
#       <td id="T_bbe3e_row5_col4" class="data row5 col4" >0.0759</td>
#       <td id="T_bbe3e_row5_col5" class="data row5 col5" >0.3124</td>
#       <td id="T_bbe3e_row5_col6" class="data row5 col6" >0.4624</td>
#       <td id="T_bbe3e_row5_col7" class="data row5 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_bbe3e_level0_row6" class="row_heading level0 row6" >dt</th>
#       <td id="T_bbe3e_row6_col0" class="data row6 col0" >Decision Tree Regressor</td>
#       <td id="T_bbe3e_row6_col1" class="data row6 col1" >0.3055</td>
#       <td id="T_bbe3e_row6_col2" class="data row6 col2" >0.3055</td>
#       <td id="T_bbe3e_row6_col3" class="data row6 col3" >0.5496</td>
#       <td id="T_bbe3e_row6_col4" class="data row6 col4" >-0.3843</td>
#       <td id="T_bbe3e_row6_col5" class="data row6 col5" >0.3810</td>
#       <td id="T_bbe3e_row6_col6" class="data row6 col6" >0.4336</td>
#       <td id="T_bbe3e_row6_col7" class="data row6 col7" >0.4400</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### *Resolver*
# #### 2. ¿Por qué escogiste estos 7 modelos en la lista de include?. Si deseas puedes ayudarte del ordenamiento

# %% [markdown]
# # Paso 4 (Opcional):Ordenamiento de los mejores modelos respecto de una métrica

# %%
Mejores_Modelos_TOP3_MAE = ExperimentoRegresion.compare_models(sort = 'R2', n_select = 3)
# Out:
# <style type="text/css">
# #T_cf6bc th {
#   text-align: left;
# }
# #T_cf6bc_row0_col0, #T_cf6bc_row0_col1, #T_cf6bc_row0_col5, #T_cf6bc_row0_col6, #T_cf6bc_row1_col0, #T_cf6bc_row1_col1, #T_cf6bc_row1_col2, #T_cf6bc_row1_col3, #T_cf6bc_row1_col4, #T_cf6bc_row1_col6, #T_cf6bc_row2_col0, #T_cf6bc_row2_col1, #T_cf6bc_row2_col2, #T_cf6bc_row2_col3, #T_cf6bc_row2_col4, #T_cf6bc_row2_col5, #T_cf6bc_row2_col6, #T_cf6bc_row3_col0, #T_cf6bc_row3_col1, #T_cf6bc_row3_col2, #T_cf6bc_row3_col3, #T_cf6bc_row3_col4, #T_cf6bc_row3_col5, #T_cf6bc_row3_col6, #T_cf6bc_row4_col0, #T_cf6bc_row4_col1, #T_cf6bc_row4_col2, #T_cf6bc_row4_col3, #T_cf6bc_row4_col4, #T_cf6bc_row4_col5, #T_cf6bc_row4_col6, #T_cf6bc_row5_col0, #T_cf6bc_row5_col1, #T_cf6bc_row5_col2, #T_cf6bc_row5_col3, #T_cf6bc_row5_col4, #T_cf6bc_row5_col5, #T_cf6bc_row5_col6, #T_cf6bc_row6_col0, #T_cf6bc_row6_col1, #T_cf6bc_row6_col2, #T_cf6bc_row6_col3, #T_cf6bc_row6_col4, #T_cf6bc_row6_col5, #T_cf6bc_row6_col6, #T_cf6bc_row7_col0, #T_cf6bc_row7_col1, #T_cf6bc_row7_col2, #T_cf6bc_row7_col3, #T_cf6bc_row7_col4, #T_cf6bc_row7_col5, #T_cf6bc_row7_col6, #T_cf6bc_row8_col0, #T_cf6bc_row8_col1, #T_cf6bc_row8_col2, #T_cf6bc_row8_col3, #T_cf6bc_row8_col4, #T_cf6bc_row8_col5, #T_cf6bc_row8_col6, #T_cf6bc_row9_col0, #T_cf6bc_row9_col1, #T_cf6bc_row9_col2, #T_cf6bc_row9_col3, #T_cf6bc_row9_col4, #T_cf6bc_row9_col5, #T_cf6bc_row9_col6, #T_cf6bc_row10_col0, #T_cf6bc_row10_col1, #T_cf6bc_row10_col2, #T_cf6bc_row10_col3, #T_cf6bc_row10_col4, #T_cf6bc_row10_col5, #T_cf6bc_row10_col6, #T_cf6bc_row11_col0, #T_cf6bc_row11_col1, #T_cf6bc_row11_col2, #T_cf6bc_row11_col3, #T_cf6bc_row11_col4, #T_cf6bc_row11_col5, #T_cf6bc_row11_col6, #T_cf6bc_row12_col0, #T_cf6bc_row12_col1, #T_cf6bc_row12_col2, #T_cf6bc_row12_col3, #T_cf6bc_row12_col4, #T_cf6bc_row12_col5, #T_cf6bc_row12_col6, #T_cf6bc_row13_col0, #T_cf6bc_row13_col1, #T_cf6bc_row13_col2, #T_cf6bc_row13_col3, #T_cf6bc_row13_col4, #T_cf6bc_row13_col5, #T_cf6bc_row13_col6, #T_cf6bc_row14_col0, #T_cf6bc_row14_col1, #T_cf6bc_row14_col2, #T_cf6bc_row14_col3, #T_cf6bc_row14_col4, #T_cf6bc_row14_col5, #T_cf6bc_row14_col6, #T_cf6bc_row15_col0, #T_cf6bc_row15_col1, #T_cf6bc_row15_col2, #T_cf6bc_row15_col3, #T_cf6bc_row15_col4, #T_cf6bc_row15_col5, #T_cf6bc_row15_col6, #T_cf6bc_row16_col0, #T_cf6bc_row16_col1, #T_cf6bc_row16_col2, #T_cf6bc_row16_col3, #T_cf6bc_row16_col4, #T_cf6bc_row16_col5, #T_cf6bc_row16_col6, #T_cf6bc_row17_col0, #T_cf6bc_row17_col1, #T_cf6bc_row17_col2, #T_cf6bc_row17_col3, #T_cf6bc_row17_col4, #T_cf6bc_row17_col5, #T_cf6bc_row17_col6, #T_cf6bc_row18_col0, #T_cf6bc_row18_col2, #T_cf6bc_row18_col3, #T_cf6bc_row18_col4, #T_cf6bc_row18_col5, #T_cf6bc_row19_col0, #T_cf6bc_row19_col1, #T_cf6bc_row19_col2, #T_cf6bc_row19_col3, #T_cf6bc_row19_col4, #T_cf6bc_row19_col5, #T_cf6bc_row19_col6 {
#   text-align: left;
# }
# #T_cf6bc_row0_col2, #T_cf6bc_row0_col3, #T_cf6bc_row0_col4, #T_cf6bc_row1_col5, #T_cf6bc_row18_col1, #T_cf6bc_row18_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cf6bc_row0_col7, #T_cf6bc_row1_col7, #T_cf6bc_row2_col7, #T_cf6bc_row3_col7, #T_cf6bc_row4_col7, #T_cf6bc_row6_col7, #T_cf6bc_row7_col7, #T_cf6bc_row8_col7, #T_cf6bc_row9_col7, #T_cf6bc_row10_col7, #T_cf6bc_row11_col7, #T_cf6bc_row12_col7, #T_cf6bc_row13_col7, #T_cf6bc_row14_col7, #T_cf6bc_row15_col7, #T_cf6bc_row16_col7, #T_cf6bc_row17_col7, #T_cf6bc_row18_col7, #T_cf6bc_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cf6bc_row5_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cf6bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf6bc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cf6bc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cf6bc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cf6bc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cf6bc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cf6bc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cf6bc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cf6bc_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf6bc_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_cf6bc_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_cf6bc_row0_col1" class="data row0 col1" >0.3223</td>
#       <td id="T_cf6bc_row0_col2" class="data row0 col2" >0.1671</td>
#       <td id="T_cf6bc_row0_col3" class="data row0 col3" >0.4074</td>
#       <td id="T_cf6bc_row0_col4" class="data row0 col4" >0.2395</td>
#       <td id="T_cf6bc_row0_col5" class="data row0 col5" >0.2875</td>
#       <td id="T_cf6bc_row0_col6" class="data row0 col6" >0.4652</td>
#       <td id="T_cf6bc_row0_col7" class="data row0 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_cf6bc_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_cf6bc_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_cf6bc_row1_col1" class="data row1 col1" >0.3166</td>
#       <td id="T_cf6bc_row1_col2" class="data row1 col2" >0.1686</td>
#       <td id="T_cf6bc_row1_col3" class="data row1 col3" >0.4078</td>
#       <td id="T_cf6bc_row1_col4" class="data row1 col4" >0.2343</td>
#       <td id="T_cf6bc_row1_col5" class="data row1 col5" >0.2868</td>
#       <td id="T_cf6bc_row1_col6" class="data row1 col6" >0.4671</td>
#       <td id="T_cf6bc_row1_col7" class="data row1 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_cf6bc_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_cf6bc_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_cf6bc_row2_col1" class="data row2 col1" >0.3463</td>
#       <td id="T_cf6bc_row2_col2" class="data row2 col2" >0.1683</td>
#       <td id="T_cf6bc_row2_col3" class="data row2 col3" >0.4094</td>
#       <td id="T_cf6bc_row2_col4" class="data row2 col4" >0.2338</td>
#       <td id="T_cf6bc_row2_col5" class="data row2 col5" >0.2871</td>
#       <td id="T_cf6bc_row2_col6" class="data row2 col6" >0.4958</td>
#       <td id="T_cf6bc_row2_col7" class="data row2 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_cf6bc_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_cf6bc_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_cf6bc_row3_col1" class="data row3 col1" >0.3462</td>
#       <td id="T_cf6bc_row3_col2" class="data row3 col2" >0.1684</td>
#       <td id="T_cf6bc_row3_col3" class="data row3 col3" >0.4095</td>
#       <td id="T_cf6bc_row3_col4" class="data row3 col4" >0.2336</td>
#       <td id="T_cf6bc_row3_col5" class="data row3 col5" >0.2872</td>
#       <td id="T_cf6bc_row3_col6" class="data row3 col6" >0.4958</td>
#       <td id="T_cf6bc_row3_col7" class="data row3 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_cf6bc_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_cf6bc_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_cf6bc_row4_col1" class="data row4 col1" >0.3456</td>
#       <td id="T_cf6bc_row4_col2" class="data row4 col2" >0.1686</td>
#       <td id="T_cf6bc_row4_col3" class="data row4 col3" >0.4098</td>
#       <td id="T_cf6bc_row4_col4" class="data row4 col4" >0.2322</td>
#       <td id="T_cf6bc_row4_col5" class="data row4 col5" >0.2871</td>
#       <td id="T_cf6bc_row4_col6" class="data row4 col6" >0.4952</td>
#       <td id="T_cf6bc_row4_col7" class="data row4 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_cf6bc_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_cf6bc_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_cf6bc_row5_col1" class="data row5 col1" >0.3507</td>
#       <td id="T_cf6bc_row5_col2" class="data row5 col2" >0.1691</td>
#       <td id="T_cf6bc_row5_col3" class="data row5 col3" >0.4104</td>
#       <td id="T_cf6bc_r

# %% [markdown]
# # Paso 5: Tuneamos los hypermarámetros del Mejor Modelo

# %%
# Ahora seleccionas uno de esos modelos para tunearlo
MejorModelo = Mejores_Modelos_TOP3_MAE[0]  # Selecciona el mejor de los tres

# %%
MejorModelo_Tuneado = ExperimentoRegresion.tune_model(estimator=MejorModelo)
# Out:
# <style type="text/css">
# #T_b3401_row10_col0, #T_b3401_row10_col1, #T_b3401_row10_col2, #T_b3401_row10_col3, #T_b3401_row10_col4, #T_b3401_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b3401">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3401_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b3401_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b3401_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b3401_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b3401_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b3401_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3401_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3401_row0_col0" class="data row0 col0" >0.3864</td>
#       <td id="T_b3401_row0_col1" class="data row0 col1" >0.1829</td>
#       <td id="T_b3401_row0_col2" class="data row0 col2" >0.4277</td>
#       <td id="T_b3401_row0_col3" class="data row0 col3" >0.1519</td>
#       <td id="T_b3401_row0_col4" class="data row0 col4" >0.3047</td>
#       <td id="T_b3401_row0_col5" class="data row0 col5" >0.5551</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3401_row1_col0" class="data row1 col0" >0.4230</td>
#       <td id="T_b3401_row1_col1" class="data row1 col1" >0.2128</td>
#       <td id="T_b3401_row1_col2" class="data row1 col2" >0.4613</td>
#       <td id="T_b3401_row1_col3" class="data row1 col3" >0.1440</td>
#       <td id="T_b3401_row1_col4" class="data row1 col4" >0.3086</td>
#       <td id="T_b3401_row1_col5" class="data row1 col5" >0.5822</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3401_row2_col0" class="data row2 col0" >0.3659</td>
#       <td id="T_b3401_row2_col1" class="data row2 col1" >0.1666</td>
#       <td id="T_b3401_row2_col2" class="data row2 col2" >0.4082</td>
#       <td id="T_b3401_row2_col3" class="data row2 col3" >0.2276</td>
#       <td id="T_b3401_row2_col4" class="data row2 col4" >0.2879</td>
#       <td id="T_b3401_row2_col5" class="data row2 col5" >0.5422</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3401_row3_col0" class="data row3 col0" >0.3791</td>
#       <td id="T_b3401_row3_col1" class="data row3 col1" >0.1895</td>
#       <td id="T_b3401_row3_col2" class="data row3 col2" >0.4353</td>
#       <td id="T_b3401_row3_col3" class="data row3 col3" >0.1474</td>
#       <td id="T_b3401_row3_col4" class="data row3 col4" >0.3008</td>
#       <td id="T_b3401_row3_col5" class="data row3 col5" >0.6057</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3401_row4_col0" class="data row4 col0" >0.3551</td>
#       <td id="T_b3401_row4_col1" class="data row4 col1" >0.1661</td>
#       <td id="T_b3401_row4_col2" class="data row4 col2" >0.4075</td>
#       <td id="T_b3401_row4_col3" class="data row4 col3" >0.1723</td>
#       <td id="T_b3401_row4_col4" class="data row4 col4" >0.2906</td>
#       <td id="T_b3401_row4_col5" class="data row4 col5" >0.5789</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3401_row5_col0" class="data row5 col0" >0.3446</td>
#       <td id="T_b3401_row5_col1" class="data row5 col1" >0.1456</td>
#       <td id="T_b3401_row5_col2" class="data row5 col2" >0.3816</td>
#       <td id="T_b3401_row5_col3" class="data row5 col3" >0.2740</td>
#       <td id="T_b3401_row5_col4" class="data row5 col4" >0.2762</td>
#       <td id="T_b3401_row5_col5" class="data row5 col5" >0.5112</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3401_row6_col0" class="data row6 col0" >0.3548</td>
#       <td id="T_b3401_row6_col1" class="data row6 col1" >0.1560</td>
#       <td id="T_b3401_row6_col2" class="data row6 col2" >0.3950</td>
#       <td id="T_b3401_row6_col3" class="data row6 col3" >0.2516</td>
#       <td id="T_b3401_row6_col4" class="data row6 col4" >0.2803</td>
#       <td id="T_b3401_row6_col5" class="data row6 col5" >0.5618</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3401_row7_col0" class="data row7 col0" >0.3873</td>
#       <td id="T_b3401_row7_col1" class="data row7 col1" >0.1832</td>
#       <td id="T_b3401_row7_col2" class="data row7 col2" >0.4281</td>
#       <td id="T_b3401_row7_col3" class="data row7 col3" >0.2201</td>
#       <td id="T_b3401_row7_col4" class="data row7 col4" >0.2977</td>
#       <td id="T_b3401_row7_col5" class="data row7 col5" >0.5477</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3401_row8_col0" class="data row8 col0" >0.3413</td>
#       <td id="T_b3401_row8_col1" class="data row8 col1" >0.1437</td>
#       <td id="T_b3401_row8_col2" class="data row8 col2" >0.3791</td>
#       <td id="T_b3401_row8_col3" class="data row8 col3" >0.3592</td>
#       <td id="T_b3401_row8_col4" class="data row8 col4" >0.2682</td>
#       <td id="T_b3401_row8_col5" class="data row8 col5" >0.4862</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3401_row9_col0" class="data row9 col0" >0.3514</td>
#       <td id="T_b3401_row9_col1" class="data row9 col1" >0.1586</td>
#       <td id="T_b3401_row9_col2" class="data row9 col2" >0.3983</td>
#       <td id="T_b3401_row9_col3" class="data row9 col3" >0.3103</td>
#       <td id="T_b3401_row9_col4" class="data row9 col4" >0.2704</td>
#       <td id="T_b3401_row9_col5" class="data row9 col5" >0.5657</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b3401_row10_col0" class="data row10 col0" >0.3689</td>
#       <td id="T_b3401_row10_col1" class="data row10 col1" >0.1705</td>
#       <td id="T_b3401_row10_col2" class="data row10 col2" >0.4122</td>
#       <td id="T_b3401_row10_col3" class="data row10 col3" >0.2258</td>
#       <td id="T_b3401_row10_col4" class="data row10 col4" >0.2885</td>
#       <td id="T_b3401_row10_col5" class="data row10 col5" >0.5537</td>
#     </tr>
#     <tr>
#       <th id="T_b3401_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b3401_row11_col0" class="data row11 col0" >0.0239</td>
#       <td id="T_b3401_row11_col1" class="data row11 col1" >0.0205</td>
#       <td id="T_b3401_row11_col2" class="data row11 col2" >0.0245</td>
#       <td id="T_b3401_row11_col3" class="data row11 col3" >0.0701</td>
#       <td id="T_b3401_row11_col4" class="data row11 col4" >0.0137</td>
#       <td id="T_b3401_row11_col5" class="data row11 col5" >0.0330</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# ### *Resolver*
# #### 3. ¿El mejor modelo tuneado ha tenido mejores valores de salida respecto a las métrica que el mejor modelo sin tunear?. Si tuvo o no, justifica tu respuesta.

# %% [markdown]
# # Paso 6: Finalizar Modelo

# %%
Modelo_Final = ExperimentoRegresion.finalize_model(estimator = MejorModelo_Tuneado) #Escoger el MejorModelo o MejorModelo_Tuneado dependiendo de tu respuesta de arriba.

# %%
Modelo_Final
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Number of times pregnant',
#                                              'Plasma glucose concentration a 2 '
#                                              'hours in an oral glucose '
#                                              'tolerance test',
#                                              'Diastolic blood pressure (mm Hg)',
#                                              'Triceps skin fold thickness (mm)',
#                                              '2-Hour serum insulin (mu U/ml)',
#                                              'Body mass index (weight in '
#                                              'kg/(height in m)^2)',
#                                              'Diabetes pedigree function',
#                                              'Age (years)'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ('actual_estimator',
#                  ExtraTreesRegressor(n_jobs=-1, random_state=123))])

# %% [markdown]
# # Paso 7: Guardar Modelo

# %%
ExperimentoRegresion.save_model(model = Modelo_Final, model_name = './Modelo_Final_1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Number of times pregnant',
#                                               'Plasma glucose concentration a 2 '
#                                               'hours in an oral glucose '
#                                               'tolerance test',
#                                               'Diastolic blood pressure (mm Hg)',
#                                               'Triceps skin fold thickness (mm)',
#                                               '2-Hour serum insulin (mu U/ml)',
#                                               'Body mass index (weight in '
#                                               'kg/(height in m)^2)',
#                                               'Diabetes pedigree function',
#                                               'Age (years)'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('actual_estimator',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=123))]),
#  './Modelo_Final_1.pkl')

# %%
import joblib
joblib.dump(MejorModelo_Tuneado, 'modelo_entrenado_solo.pkl')
# Out:
# ['modelo_entrenado_solo.pkl']

# %% [markdown]
# # Paso 8: Cargar Modelo (Hasta aquí entra la Tarea y la Evaluación)

# %%
Modelo_Cargado_desde_Disco = ExperimentoRegresion.load_model('./Modelo_Final_1')
# Out:
# Transformation Pipeline and Model Successfully Loaded
